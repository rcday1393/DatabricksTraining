# %%
print("Hi")

# %%
# %sql
select "Hi from SQL"

# %% [markdown]
# #Title1
# ##Title2
# ###Title3

# %%
# %run ./Demo1.2

# %%
print(INITIALS)

# %%
# %fs ls '/databricks-datasets'

# %%
files = dbutils.fs.ls('/databricks-datasets')

# %%
display(files)
